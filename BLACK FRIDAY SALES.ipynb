# %% [markdown]
# # IMPORTING RELEVANT LIBRARY

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # IMPORTING DATA

# %%
df = pd.read_csv('train1.csv')
df2 = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df2.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
#analysis for unique values
df.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df.Occupation.unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df.Stay_In_Current_City_Years.unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df.Marital_Status.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Product_Category_1.unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %%
df.Product_Category_2.unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df.Product_Category_3.unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df.Purchase.unique()
# Out:
# array([ 8370, 15200,  1422, ...,   135,   123,   613], dtype=int64)

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
sns.countplot(x="Gender", data = df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Age", data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Occupation", data = df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x="City_Category", data = df)
# Out:
# <AxesSubplot:xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years", data = df)
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Marital_Status", data = df)
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='count'>

# %%
sns.set_style("darkgrid")
agg_plot = df.pivot_table(values = "Purchase", index = "Age", aggfunc = np.mean)
agg_plot.plot(kind="bar", figsize = (13,7))
plt.xlabel("Age")
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.show()

# %%
agg_plot = df.pivot_table(values = "Purchase", index = "Occupation", aggfunc = np.mean)
agg_plot.plot(kind="bar", figsize = (13,7))
plt.xlabel("Occupation")
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.show()

# %%
agg_plot = df.pivot_table(values = "Purchase", index = "Gender", aggfunc = np.mean)
agg_plot.plot(kind="bar", figsize = (13,7))
plt.xlabel("Gender")
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.show()

# %%
agg_plot = df.pivot_table(values = "Purchase", index = "City_Category", aggfunc = np.mean)
agg_plot.plot(kind="bar", figsize = (13,7))
plt.xlabel("City_Category")
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.show()

# %%
agg_plot = df.pivot_table(values = "Purchase", index = "Stay_In_Current_City_Years", aggfunc = np.mean)
agg_plot.plot(kind="bar", figsize = (13,7))
plt.xlabel("Stay_In_Current_City_Years")
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.show()

# %%
agg_plot = df.pivot_table(values = "Purchase", index = "Marital_Status", aggfunc = np.mean)
agg_plot.plot(kind="bar", figsize = (13,7))
plt.xlabel("Marital_status")
plt.ylabel("Purchase")
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# # PREPROCESSING THE DATA

# %%
# label encoding
cols = ['Gender','City_Category','Age', 'Stay_In_Current_City_Years']
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0  1000001  P00069042       0    0          10              0
# 1  1000001  P00248942       0    0          10              0
# 2  1000001  P00087842       0    0          10              0
# 3  1000001  P00085442       0    0          10              0
# 4  1000002  P00285442       1    6          16              2
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#filling NaN values in Product_Category_2
df['Product_Category_2'] = df['Product_Category_2'].fillna(0).astype("float32")
df['Product_Category_3'] = df['Product_Category_3'].fillna(0).astype("float32")
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # CORRELATION MATRIX

# %%
corr = df.corr()
plt.figure(figsize=(14,7))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # INPUT SPLIT

# %%
X = df.drop(columns = ["User_ID", "Product_ID", "Purchase"])
y = df["Purchase"]

# %% [markdown]
# # TRAIN TEST SPLIT AND MODEL TRAINING

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
def train(model, X, y) :
    #train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    
    #model fitting
    model.fit(X_train, y_train)
    
    
    #predicting the result
    pred = model.predict(X_test)
    
    
    #cross validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
    
    print("Results")
    print("MSE:", np.sqrt(mean_squared_error(y_test, pred)))
    print("CV Score:", np.sqrt(cv_score))

# %% [markdown]
# ### LInear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title='Model Coefficients')
# Out:
# Results
# MSE: 4627.777465694636
# CV Score: 4628.367366331096
# <AxesSubplot:title={'center':'Model Coefficients'}>

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X, y)
features = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
features.plot(kind='bar', title='Feature Importance')
# Out:
# Results
# MSE: 3379.9978012960255
# CV Score: 3339.3587040570924
# <AxesSubplot:title={'center':'Feature Importance'}>

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_jobs=-1)
train(model, X, y)
features = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
features.plot(kind='bar', title='Feature Importance')
# Out:
# Results
# MSE: 3065.2736854706986
# CV Score: 3052.2774723515067
# <AxesSubplot:title={'center':'Feature Importance'}>
